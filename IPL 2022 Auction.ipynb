# %% [markdown]
# # Includes Topic of Python

# %% [markdown]
# ### 1. Concept of Array
# ### 2. Concept of Dictionary
# ### 3. Concept of Updation in dictionary
# ### 4. Sorting of array (with reversal)
# ### 5. For loop
# ### 6. If condition

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'IPL 2022 Auction.ipynb', 'IPL Auction 2022.csv']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("IPL Auction 2022.csv")

# %%
data
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
#which country's players were bought and sold the most
players_country=data["Country"].value_counts().to_dict()

plt.bar(players_country.keys(),players_country.values())
# Out:
# <BarContainer object of 9 artists>

# %%
data["Country"].nunique()
# Out:
# 9

# %%
data["Country"].value_counts()
# Out:
# India           122
# West Indies      14
# Australia        12
# New Zealand      11
# England          11
# South Africa      7
# Sri Lanka         4
# Afghanistan       2
# Bangladesh        1
# Name: Country, dtype: int64

# %%
data["Player"].nunique()
# Out:
# 183

# %%
data["State Association"].value_counts()
# Out:
# DDCA      13
# KSCA      12
# PCA       11
# UPCA      11
# MCA        9
# TNCA       8
# RCA        8
# CAB        5
# VCA        5
# SCA        4
# MACA       4
# HCA        4
# JSCA       4
# KCA        3
# ACA        2
# UTCA       2
# HYCA       2
# HPCA       2
# RSPB       2
# MPCA       2
# BCA        2
# GUCA       1
# ASCA       1
# OCA        1
# GCA        1
# JKCA       1
# CSCSCA     1
# BICA       1
# Name: State Association, dtype: int64

# %%
data["Specialism"].value_counts()
# Out:
# ALL-ROUNDER     70
# BOWLER          63
# BATSMAN         33
# WICKETKEEPER    18
# Name: Specialism, dtype: int64

# %%
player_type=data["Specialism"].value_counts().to_dict()

plt.bar(player_type.keys(),player_type.values())
# Out:
# <BarContainer object of 4 artists>

# %%
data["2021 Team"].nunique()
# Out:
# 8

# %%
data["2021 Team"].value_counts()
# Out:
# RR      18
# KKR     15
# PBKS    15
# MI      14
# SRH     14
# DC      13
# CSK     12
# RCB     12
# Name: 2021 Team, dtype: int64

# %%
data["C/U/A"].nunique()
# Out:
# 2

# %%
data["C/U/A"].value_counts()
# Out:
# Capped      98
# Uncapped    86
# Name: C/U/A, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Set No.              184 non-null    int64
#  1   Set Name             184 non-null    object
#  2   Player               184 non-null    object
#  3   Country              184 non-null    object
#  4   State Association    122 non-null    object
#  5   Age                  184 non-null    int64
#  6   Specialism           184 non-null    object
#  7   Batting              184 non-null    object
#  8   Bowling              184 non-null    object
#  9   IPL                  137 non-null    float64
#  10  Previous IPLTeam(s)  133 non-null    object
#  11  2021 Team            113 non-null    object
#  12  C/U/A                184 non-null    object
#  13  Base Price           184 non-null    object
#  14  Sold Price           184 non-null    object
# ...

# %%
def convertCurrancy(value):
    rupees = float(value.split(" ")[0])
    notation = value.split(" ")[1]
    if(notation == "L"):
        return rupees*100000
    else:
        return rupees*10000000

# %%
data["Base Price"] = data["Base Price"].apply(lambda value:convertCurrancy(value)) 
data["Sold Price"] = data["Sold Price"].apply(lambda value:convertCurrancy(value))

# %%
data
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
plt.plot(data["Base Price"],data["Sold Price"])

# %%
data.head(60)
# Out:
#     Set No. Set Name               Player       Country State Association  \
# 0         1        M             R Ashwin         India              TNCA
# 1         1        M          Trent Boult   New Zealand               NaN
# 2         1        M          Pat Cummins     Australia               NaN
# 3         1        M       Shikhar Dhawan         India              DDCA
# 4         1        M       Faf Du Plessis  South Africa               NaN
# 5         1        M         Shreyas Iyer         India               MCA
# 6         1        M        Kagiso Rabada  South Africa               NaN
# 7         1        M       Mohammad Shami         India               CAB
# 8         1        M         David Warner     Australia               NaN
# 9         2      BA1      Shimron Hetmyer   West Indies               NaN
# 10        2      BA1         David Miller  South Africa               NaN
# 11        2      BA1     Devdutt Padikkal         India              KSCA
# ...

# %%
data.iloc[1]
# Out:
# Set No.                                   1
# Set Name                                  M
# Player                          Trent Boult
# Country                         New Zealand
# State Association                       NaN
# Age                                      32
# Specialism                           BOWLER
# Batting                                 RHB
# Bowling                LEFT ARM Fast Medium
# IPL                                    62.0
# Previous IPLTeam(s)         SRH, KKR, DD,MI
# 2021 Team                                MI
# C/U/A                                Capped
# Base Price                       20000000.0
# Sold Price                       80000000.0
# New Franchise              Rajasthan Royals
# Name: 1, dtype: object

# %%
#num = [5,2,9,6,8,0,3,7,4]
#num.sort(reverse=True)
#print(num)

# %%
newdatas =[]
for i in range(len(data)):
    newdatas.append(data.iloc[i].to_dict())
len(newdatas)
# Out:
# 184

# %%
def convertInt(value):
    return int(value)

# %%
# updating Sold Price of newdatas
for new in newdatas:
    new["Sold Price"] = convertInt(new["Sold Price"])

# %%
soldPriceArray = []
for player in newdatas:
    soldPriceArray.append(player["Sold Price"])

# %%
soldPriceArray
# Out:
# [50000000,
#  80000000,
#  72500000,
#  82500000,
#  70000000,
#  122500000,
#  92500000,
#  62500000,
#  62500000,
#  85000000,
#  30000000,
#  77500000,
#  46000000,
#  20000000,
#  20000000,
#  44000000,
#  107500000,
#  87500000,
#  65000000,
#  82500000,
#  107500000,
#  80000000,
#  87500000,
#  67500000,
#  20000000,
#  55000000,
#  152500000,
#  107500000,
#  67500000,
#  24000000,
#  140000000,
#  100000000,
#  77500000,
#  100000000,
#  42000000,
#  20000000,
#  107500000,
#  75000000,
#  20000000,
#  65000000,
#  52500000,
#  20000000,
#  30000000,
#  2000000,
#  2000000,
#  26000000,
#  2000000,
#  85000000,
#  24000000,
#  38000000,
#  57500000,
#  2000000,
#  90000000,
#  72500000,
#  11000000,
#  38000000,
#  65000000,
#  90000000,
#  6000000,
#  34000000,
#  2000000,
#  6000000,
#  5000000,
#  2000000,
#  2000000,
#  100000000,
#  2500000,
#  3000000,
#  40000000,
#  3000000,
#  16000000,
#  7500000,
#  2000000,
#  26000000,
#  10000000,
#  11000000,
#  11000000,
# ...

# %%
soldPriceArray.sort(reverse=True)

# %%
soldPriceArray
# Out:
# [152500000,
#  140000000,
#  122500000,
#  115000000,
#  107500000,
#  107500000,
#  107500000,
#  107500000,
#  100000000,
#  100000000,
#  100000000,
#  92500000,
#  90000000,
#  90000000,
#  87500000,
#  87500000,
#  85000000,
#  85000000,
#  82500000,
#  82500000,
#  82500000,
#  80000000,
#  80000000,
#  80000000,
#  77500000,
#  77500000,
#  77500000,
#  75000000,
#  72500000,
#  72500000,
#  70000000,
#  67500000,
#  67500000,
#  65000000,
#  65000000,
#  65000000,
#  62500000,
#  62500000,
#  60000000,
#  57500000,
#  55000000,
#  52500000,
#  50000000,
#  46000000,
#  44000000,
#  42000000,
#  42000000,
#  42000000,
#  40000000,
#  40000000,
#  38000000,
#  38000000,
#  36000000,
#  34000000,
#  32000000,
#  30000000,
#  30000000,
#  28000000,
#  26000000,
#  26000000,
#  26000000,
#  26000000,
#  24000000,
#  24000000,
#  24000000,
#  24000000,
#  20000000,
#  20000000,
#  20000000,
#  20000000,
#  20000000,
#  20000000,
#  20000000,
#  20000000,
#  20000000,
#  20000000,
# ...

# %%
def findData(price):
    for newdata in newdatas:
        if(newdata["Sold Price"] == price):
            return newdata

# %%
findPlayer = []
for prices in soldPriceArray:
    findPlayer.append(findData(prices))

# %%
for play in findPlayer:
    print("NAME:",play["Player"],' COUNTRY:' ,play["Country"], "Sold:", play["Sold Price"],  "BASE:", play["Base Price"])
# Out:
# NAME: Ishan Kishan  COUNTRY: India Sold: 152500000 BASE: 20000000.0
# NAME: Deepak Chahar  COUNTRY: India Sold: 140000000 BASE: 20000000.0
# NAME: Shreyas Iyer  COUNTRY: India Sold: 122500000 BASE: 20000000.0
# NAME: Liam Livingstone  COUNTRY: England Sold: 115000000 BASE: 10000000.0
# NAME: Wanindu Hasaranga  COUNTRY: Sri Lanka Sold: 107500000 BASE: 10000000.0
# NAME: Wanindu Hasaranga  COUNTRY: Sri Lanka Sold: 107500000 BASE: 10000000.0
# NAME: Wanindu Hasaranga  COUNTRY: Sri Lanka Sold: 107500000 BASE: 10000000.0
# NAME: Wanindu Hasaranga  COUNTRY: Sri Lanka Sold: 107500000 BASE: 10000000.0
# NAME: Lockie Ferguson  COUNTRY: New Zealand Sold: 100000000 BASE: 20000000.0
# NAME: Lockie Ferguson  COUNTRY: New Zealand Sold: 100000000 BASE: 20000000.0
# NAME: Lockie Ferguson  COUNTRY: New Zealand Sold: 100000000 BASE: 20000000.0
# NAME: Kagiso Rabada  COUNTRY: South Africa Sold: 92500000 BASE: 20000000.0
# NAME: Shahrukh Khan  COUNTRY: India Sold: 90000000 BASE: 4000000.0
# ...

# %%
len(findPlayer)
# Out:
# 184
